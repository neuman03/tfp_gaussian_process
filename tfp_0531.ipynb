# %%
import tensorflow_probability as tfp
from tensorflow_probability import math as tfpm
from tensorflow_probability import distributions as tfpd

# %%
import pandas as pd

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams

rcParams['figure.figsize'] = 20,6

# %%
ls
# Out:
# daily-min-temperatures.csv     datatest2.csv
# daily-total-female-births.csv  tfp_0531.ipynb
# datatest.csv

# %% [markdown]
# ## #1 Load Data

# %%
#https://machinelearningmastery.com/time-series-datasets-for-machine-learning/
temp=pd.read_csv("daily-min-temperatures.csv")

# %%
temp.head()
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
temp.plot()

# %%
birth=pd.read_csv("daily-total-female-births.csv")
birth.head()
# Out:
#          Date  Births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
birth.plot(color="orange")

# %%
ozone=pd.read_csv("datatest.csv")
ozone.head()
# Out:
#                     date  Temperature  Humidity       Light         CO2  \
# 140  2015-02-02 14:19:00      23.7000    26.272  585.200000  749.200000
# 141  2015-02-02 14:19:59      23.7180    26.290  578.400000  760.400000
# 142  2015-02-02 14:21:00      23.7300    26.230  572.666667  769.666667
# 143  2015-02-02 14:22:00      23.7225    26.125  493.750000  774.750000
# 144  2015-02-02 14:23:00      23.7540    26.200  488.600000  779.000000
#
#      HumidityRatio  Occupancy
# 140       0.004764          1
# 141       0.004773          1
# 142       0.004765          1
# 143       0.004744          1
# 144       0.004767          1

# %%
ozone2=pd.read_csv("datatest2.csv")
ozone2.head()
# Out:
#                   date  Temperature   Humidity       Light          CO2  \
# 1  2015-02-11 14:48:00      21.7600  31.133333  437.333333  1029.666667
# 2  2015-02-11 14:49:00      21.7900  31.000000  437.333333  1000.000000
# 3  2015-02-11 14:50:00      21.7675  31.122500  434.000000  1003.750000
# 4  2015-02-11 14:51:00      21.7675  31.122500  439.000000  1009.500000
# 5  2015-02-11 14:51:59      21.7900  31.133333  437.333333  1005.666667
#
#    HumidityRatio  Occupancy
# 1       0.005021          1
# 2       0.005009          1
# 3       0.005022          1
# 4       0.005022          1
# 5       0.005030          1

# %%
ozone.plot()

# %%
ozone2.plot()

# %% [markdown]
# ## #2 Gaussian Process

# %%
tfpk=tfpm.psd_kernels
kernel=tfpk.ExponentiatedQuadratic()

# %%
gp=tfpd.GaussianProcess(kernel)
